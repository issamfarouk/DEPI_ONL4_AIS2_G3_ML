# %%
print("welcome to DEPI")
# Out:
# welcome to DEPI

# %%
x=4
print("welcome to DEPI Round", x)
# Out:
# welcome to DEPI Round 4

# %%
x=4
print("welcome to DEPI", hex(id(x)))
# Out:
# welcome to DEPI 0x7ffa4a70ea18

# %%
x = 3
print(type(x))
# Out:
# <class 'int'>

# %%
x = "DEPI"
print(type(x))
# Out:
# <class 'str'>

# %%
name = "mohamed"
id = "111"
print(name,id)
# Out:
# mohamed 111

# %%
x = 20
y = 30
# print("this is value =",x, "and y value is  =",y)
print("this is x {} and y {}".format(x,y))
# Out:
# this is x 20 and y 30

# %%
x = 20
y = 30
print(f"This is x = {x} and y = {y}")
# Out:
# This is x = 20 and y = 30

# %%
name = "ArithmeticError"
course_name= "ml"
id = "26"
print(f"The name is {name} and Course name is {course_name} and id {id}")
# Out:
# The name is ArithmeticError and Course name is ml and id 26

# %%
name = "DEPI R4"
name[0:3]
# Out:
# 'DEP'

# %%
name = "DEPI R4"
name[0:4:2]
# Out:
# 'DP'

# %%
name = "welcome into depi r4"
upper_text = name.upper()
print(upper_text)
# Out:
# WELCOME INTO DEPI R4

# %%
lower_text = upper_text.lower()
print(lower_text)
# Out:
# welcome into depi r4

# %%
name = "welcome into depi r4"
name.replace("r4", "r5")
# Out:
# 'welcome into depi r5'

# %%
name = "welcome into depi r4"
name.title()
# Out:
# 'Welcome Into Depi R4'

# %%
name = "welcome into depi r4"
name.capitalize()
# Out:
# 'Welcome into depi r4'

# %%
name = "welcome into depi r4 r4"
name.count("r4")
# Out:
# 2

# %%
name = "welcome into depi r4"
name.split()
# Out:
# ['welcome', 'into', 'depi', 'r4']

# %%
name.startswith("welcome")
# Out:
# True

# %%
name.endswith("depi")
# Out:
# False
